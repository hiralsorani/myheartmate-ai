# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import joblib  # For saving and loading model

# ------------------ Load Data ------------------
df = pd.read_csv('cardio_train_cleaned.csv')

X = df.drop('cardio', axis=1)
y = df['cardio']

# ------------------ Split Data ------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=50
)

# ------------------ Scale Features ------------------
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ------------------ Train Model ------------------
model = LogisticRegression(max_iter=50000)
model.fit(X_train, y_train)

# ------------------ Evaluate ------------------
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred) * 100
print(f"Accuracy: {accuracy:.2f}%")

# ------------------ Save Model & Scaler ------------------
# Save the trained model
joblib.dump(model, 'cardio_model.pkl')

# Save the scaler as well (needed for new inputs)
joblib.dump(scaler, 'scaler.pkl')

print("Model and scaler saved as 'cardio_model.pkl' and 'scaler.pkl'.")
# Out:
# Accuracy: 71.66%
# Model and scaler saved as 'cardio_model.pkl' and 'scaler.pkl'.

# %%
print('a')
# Out:
# a

# %%
accuracy = accuracy_score(y_test, y_pred) 

print(f"Accuracy: {accuracy}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7275777913361806
#
# Confusion Matrix:
#  [[4917 1487]
#  [2085 4623]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.77      0.73      6404
#          1.0       0.76      0.69      0.72      6708
#
#     accuracy                           0.73     13112
#    macro avg       0.73      0.73      0.73     13112
# weighted avg       0.73      0.73      0.73     13112

# %%
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0         2.0   168.0    62.0  110.0   80.0          1.0   1.0    0.0   0.0
# 1         1.0   156.0    85.0  140.0   90.0          3.0   1.0    0.0   0.0
# 2         1.0   165.0    64.0  130.0   70.0          3.0   1.0    0.0   0.0
# 3         2.0   169.0    82.0  150.0  100.0          1.0   1.0    0.0   0.0
# 4         1.0   156.0    56.0  100.0   60.0          1.0   1.0    0.0   0.0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 65555     1.0   165.0    80.0  150.0   80.0          1.0   1.0    0.0   0.0
# 65556     1.0   158.0   126.0  140.0   90.0          2.0   2.0    0.0   0.0
# 65557     2.0   183.0   105.0  180.0   90.0          3.0   1.0    0.0   1.0
# 65558     1.0   163.0    72.0  135.0   80.0          1.0   2.0    0.0   0.0
# 65559     1.0   170.0    72.0  120.0   80.0          2.0   1.0    0.0   0.0
#
#        active  cardio  age_years        BMI  pulse_pressure
# 0         1.0     0.0       50.0  21.967120            30.0
# 1         1.0     1.0       55.0  34.927679            50.0
# 2         0.0     1.0       51.0  23.507805            60.0
# 3         1.0     1.0       48.0  28.710479            50.0
# 4         0.0     0.0       47.0  23.011177            40.0
# ...       ...     ...        ...        ...             ...
# 65555     1.0     1.0       57.0  29.384757            70.0
# 65556     1.0     1.0       61.0  50.472681            50.0
# 65557     0.0     1.0       52.0  31.353579            90.0
# 65558     0.0     1.0       61.0  27.099251            55.0
# 65559     1.0     0.0       56.0  24.913495            40.0
#
# [65560 rows x 14 columns]
